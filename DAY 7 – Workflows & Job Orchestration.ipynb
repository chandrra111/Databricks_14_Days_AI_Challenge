# %%
# Add widgets for parameters
dbutils.widgets.text(name="source_path",defaultValue="/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")
dbutils.widgets.dropdown(name="layer",defaultValue="bronze",choices=["bronze", "silver", "gold"])

# %%
from pyspark.sql import functions as F

source_path = dbutils.widgets.get("source_path")
layer = dbutils.widgets.get("layer")
